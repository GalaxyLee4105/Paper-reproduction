# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Lambda
from keras import backend as K
from sklearn.metrics import roc_auc_score
import random
import warnings


warnings.filterwarnings("ignore")
random.seed(3)
np.random.seed(3)

batch_size = 1024
seed = 3
tf.set_random_seed(seed)

# 自定义AUC指标，使用tf.py_func包装scikit-learn的roc_auc_score
def auc_roc(y_true, y_pred):
    def fallback_auc(y_true, y_pred):
        try:
            return roc_auc_score(y_true, y_pred)
        except:
            return 0.5
    return tf.py_func(fallback_auc, (y_true, y_pred), tf.float64)

def to_categorical(y, num_classes=None, dtype='float32'):
    y = np.array(y, dtype='int')
    input_shape = y.shape
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])
    y = y.ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical

def data_preparation():
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    train_df = pd.read_csv('./DATA/census-income.data', delimiter=',', header=None, index_col=None, names=column_names)
    test_df = pd.read_csv('./DATA/census-income.test', delimiter=',', header=None, index_col=None, names=column_names)

    label_columns = ['income_50k', 'marital_stat']
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_transformed = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    test_transformed = pd.get_dummies(test_df.drop(label_columns, axis=1), columns=categorical_columns)
    train_labels = train_df[label_columns]
    test_labels = test_df[label_columns]

    # 确保测试集和训练集有相同的特征列
    missing_cols = set(train_transformed.columns) - set(test_transformed.columns)
    for c in missing_cols:
        test_transformed[c] = 0
    # 确保列顺序一致
    test_transformed = test_transformed[train_transformed.columns]

    train_income = to_categorical((train_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((test_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((test_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {'income': train_income.shape[1], 'marital': train_marital.shape[1]}
    dict_train_labels = {'income': train_income, 'marital': train_marital}
    dict_other_labels = {'income': other_income, 'marital': other_marital}

    validation_indices = test_transformed.sample(frac=0.5, replace=False, random_state=seed).index
    test_indices = list(set(test_transformed.index) - set(validation_indices))
    validation_data = test_transformed.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = test_transformed.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = train_transformed
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, dict_outputs

def build_mmoe(input_dim, num_experts=6, experts_out=16, experts_hidden=32, towers_hidden=8, num_tasks=2):
    inputs = Input(shape=(input_dim,))

    # Experts
    experts = []
    for i in range(num_experts):
        x = Dense(experts_hidden, activation='relu')(inputs)
        x = Dropout(0.3)(x)
        x = Dense(experts_out)(x)
        experts.append(x)

    # 堆叠 expert 输出: (batch, num_experts, experts_out)
    expert_stack = Lambda(lambda x: K.stack(x, axis=1))(experts)

    outputs = []
    # 为每个任务定义明确的名称
    task_names = ['income_output', 'marital_output']
    for t in range(num_tasks):
        # gate (batch, num_experts)
        gate = Dense(num_experts, activation='softmax')(inputs)
        gate = Lambda(lambda g: K.expand_dims(g, axis=-1))(gate)  # (batch, num_experts, 1)

        # 加权求和 experts
        tower_input = Lambda(lambda z: K.sum(z[0] * z[1], axis=1))([expert_stack, gate])

        # Tower
        tower = Dense(towers_hidden, activation='relu')(tower_input)
        tower = Dropout(0.4)(tower)
        # 使用明确的任务名称作为输出层名称
        tower_output = Dense(1, activation='sigmoid', name=task_names[t])(tower)
        outputs.append(tower_output)

    model = Model(inputs=inputs, outputs=outputs)
    return model, task_names


# 数据准备
train_data, train_label, val_data, val_label, test_data, test_label, output_info = data_preparation()
input_dim = train_data.shape[1]

# 建模 - 获取模型和任务名称
model, task_names = build_mmoe(input_dim=input_dim, num_experts = 8, experts_out=16,
                   experts_hidden = 16, towers_hidden = 8, num_tasks = 2)

# 编译模型
model.compile(
    optimizer=tf.train.AdamOptimizer(1e-4),
    loss = 'binary_crossentropy',
    metrics = [auc_roc]
)

print(model.summary())

# 训练 - 使用与模型输出层匹配的标签名称
history = model.fit(
    train_data.values,
    {task_names[0]: train_label[0][:,1], task_names[1]: train_label[1][:,1]},
    validation_data = (
        val_data.values, 
        {task_names[0]: val_label[0][:,1], task_names[1]: val_label[1][:,1]}
    ),
    epochs = 50,
    batch_size = batch_size
)

# 测试
res = model.evaluate(
    test_data.values, 
    {task_names[0]: test_label[0][:,1], task_names[1]: test_label[1][:,1]}
)
print("Test results:", res)

# 输出每个任务的AUC
print(f"Test {task_names[0]} Loss: {res[0]}")
print(f"Test {task_names[0]} AUC: {res[1]}")
print(f"Test {task_names[1]} AUC: {res[2]}")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tmp/ipykernel_1158/2476359497.py:18: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tmp/ipykernel_1158/2476359497.py:141: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tmp/ipykernel_1158/2476359497.py:27: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 499)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 16)           8000        input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16)           0           dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16)           0           dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16)           0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           272         dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           272         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           272         dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 16)           272         dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 16)           272         dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 16)           272         dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 16)           272         dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 16)           272         dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 8)            4000        input_1[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 8)            4000        input_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 8, 16)        0           dense_2[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_8[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_14[0][0]
#                                                                  dense_16[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 8, 1)         0           dense_17[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 8, 1)         0           dense_19[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16)           0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16)           0           lambda_1[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 8)            136         lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 8)            136         lambda_5[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8)            0           dense_18[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8)            0           dense_20[0][0]
# __________________________________________________________________________________________________
# income_output (Dense)           (None, 1)            9           dropout_9[0][0]
# __________________________________________________________________________________________________
# marital_output (Dense)          (None, 1)            9           dropout_10[0][0]
# ==================================================================================================
# Total params: 74,466
# Trainable params: 74,466
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 199523 samples, validate on 49881 samples
# Epoch 1/50
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 2025-08-20 09:21:41.267579: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2025-08-20 09:21:41.275976: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2687995000 Hz
# 2025-08-20 09:21:41.280616: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x169e2a80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-08-20 09:21:41.280654: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-08-20 09:21:41.285667: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
# 2025-08-20 09:21:41.568729: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-20 09:21:41.568893: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1cb690d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-20 09:21:41.568912: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-08-20 09:21:41.569146: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-20 09:21:41.569189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3060 Laptop GPU major: 8 minor: 6 memoryClockRate(GHz): 1.425
# pciBusID: 0000:01:00.0
# 2025-08-20 09:21:41.569314: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569390: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569432: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569486: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569527: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569578: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569680: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.8/lib64
# 2025-08-20 09:21:41.569700: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-08-20 09:21:41.569715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-08-20 09:21:41.569720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2025-08-20 09:21:41.569723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# WARNING:tensorflow:From /home/glubuntu/miniconda3/envs/tf115py37/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 199523/199523 [==============================] - 6s 29us/step - loss: 6.4799 - income_output_loss: 1.1427 - marital_output_loss: 5.3373 - income_output_auc_roc: 0.5145 - marital_output_auc_roc: 0.5855 - val_loss: 2.9257 - val_income_output_loss: 0.9949 - val_marital_output_loss: 1.9308 - val_income_output_auc_roc: 0.4981 - val_marital_output_auc_roc: 0.8327
# Epoch 2/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 3.6055 - income_output_loss: 1.0512 - marital_output_loss: 2.5543 - income_output_auc_roc: 0.5096 - marital_output_auc_roc: 0.7631 - val_loss: 2.4732 - val_income_output_loss: 0.9943 - val_marital_output_loss: 1.4789 - val_income_output_auc_roc: 0.4968 - val_marital_output_auc_roc: 0.8601
# Epoch 3/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 2.6937 - income_output_loss: 0.9866 - marital_output_loss: 1.7071 - income_output_auc_roc: 0.5093 - marital_output_auc_roc: 0.8035 - val_loss: 2.3576 - val_income_output_loss: 0.9935 - val_marital_output_loss: 1.3640 - val_income_output_auc_roc: 0.4992 - val_marital_output_auc_roc: 0.8391
# Epoch 4/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 2.2530 - income_output_loss: 0.9695 - marital_output_loss: 1.2834 - income_output_auc_roc: 0.5071 - marital_output_auc_roc: 0.8018 - val_loss: 1.8311 - val_income_output_loss: 0.9917 - val_marital_output_loss: 0.8394 - val_income_output_auc_roc: 0.5000 - val_marital_output_auc_roc: 0.8318
# Epoch 5/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 2.0183 - income_output_loss: 0.9644 - marital_output_loss: 1.0539 - income_output_auc_roc: 0.5040 - marital_output_auc_roc: 0.7833 - val_loss: 1.7318 - val_income_output_loss: 0.9898 - val_marital_output_loss: 0.7420 - val_income_output_auc_roc: 0.5004 - val_marital_output_auc_roc: 0.7974
# Epoch 6/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 1.8795 - income_output_loss: 0.9556 - marital_output_loss: 0.9239 - income_output_auc_roc: 0.5031 - marital_output_auc_roc: 0.7762 - val_loss: 1.5470 - val_income_output_loss: 0.9854 - val_marital_output_loss: 0.5616 - val_income_output_auc_roc: 0.4997 - val_marital_output_auc_roc: 0.8721
# Epoch 7/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 1.7323 - income_output_loss: 0.9515 - marital_output_loss: 0.7808 - income_output_auc_roc: 0.4993 - marital_output_auc_roc: 0.7880 - val_loss: 1.5264 - val_income_output_loss: 0.9776 - val_marital_output_loss: 0.5488 - val_income_output_auc_roc: 0.4992 - val_marital_output_auc_roc: 0.8662
# Epoch 8/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 1.6555 - income_output_loss: 0.9367 - marital_output_loss: 0.7188 - income_output_auc_roc: 0.4993 - marital_output_auc_roc: 0.7960 - val_loss: 1.4789 - val_income_output_loss: 0.9702 - val_marital_output_loss: 0.5087 - val_income_output_auc_roc: 0.4983 - val_marital_output_auc_roc: 0.8881
# Epoch 9/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 1.5942 - income_output_loss: 0.9213 - marital_output_loss: 0.6729 - income_output_auc_roc: 0.4952 - marital_output_auc_roc: 0.8106 - val_loss: 1.4026 - val_income_output_loss: 0.9538 - val_marital_output_loss: 0.4488 - val_income_output_auc_roc: 0.4923 - val_marital_output_auc_roc: 0.9065
# Epoch 10/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 1.4950 - income_output_loss: 0.8703 - marital_output_loss: 0.6246 - income_output_auc_roc: 0.4797 - marital_output_auc_roc: 0.8220 - val_loss: 1.1159 - val_income_output_loss: 0.6858 - val_marital_output_loss: 0.4302 - val_income_output_auc_roc: 0.4151 - val_marital_output_auc_roc: 0.9048
# Epoch 11/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 1.3490 - income_output_loss: 0.7716 - marital_output_loss: 0.5773 - income_output_auc_roc: 0.4409 - marital_output_auc_roc: 0.8322 - val_loss: 0.9533 - val_income_output_loss: 0.5761 - val_marital_output_loss: 0.3772 - val_income_output_auc_roc: 0.4666 - val_marital_output_auc_roc: 0.9200
# Epoch 12/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 1.2372 - income_output_loss: 0.6938 - marital_output_loss: 0.5435 - income_output_auc_roc: 0.4738 - marital_output_auc_roc: 0.8474 - val_loss: 0.8423 - val_income_output_loss: 0.4868 - val_marital_output_loss: 0.3555 - val_income_output_auc_roc: 0.5721 - val_marital_output_auc_roc: 0.9261
# Epoch 13/50
# 199523/199523 [==============================] - 5s 26us/step - loss: 1.1465 - income_output_loss: 0.6349 - marital_output_loss: 0.5117 - income_output_auc_roc: 0.4948 - marital_output_auc_roc: 0.8567 - val_loss: 0.8442 - val_income_output_loss: 0.4945 - val_marital_output_loss: 0.3497 - val_income_output_auc_roc: 0.5838 - val_marital_output_auc_roc: 0.9301
# Epoch 14/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 1.0751 - income_output_loss: 0.5810 - marital_output_loss: 0.4941 - income_output_auc_roc: 0.5178 - marital_output_auc_roc: 0.8611 - val_loss: 0.8077 - val_income_output_loss: 0.4689 - val_marital_output_loss: 0.3388 - val_income_output_auc_roc: 0.5924 - val_marital_output_auc_roc: 0.9352
# Epoch 15/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 1.0105 - income_output_loss: 0.5396 - marital_output_loss: 0.4710 - income_output_auc_roc: 0.5482 - marital_output_auc_roc: 0.8688 - val_loss: 0.7460 - val_income_output_loss: 0.4449 - val_marital_output_loss: 0.3012 - val_income_output_auc_roc: 0.6140 - val_marital_output_auc_roc: 0.9456
# Epoch 16/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.9138 - income_output_loss: 0.4697 - marital_output_loss: 0.4441 - income_output_auc_roc: 0.5775 - marital_output_auc_roc: 0.8886 - val_loss: 0.7233 - val_income_output_loss: 0.4234 - val_marital_output_loss: 0.2999 - val_income_output_auc_roc: 0.6266 - val_marital_output_auc_roc: 0.9476
# Epoch 17/50
# 199523/199523 [==============================] - 5s 25us/step - loss: 0.8564 - income_output_loss: 0.4298 - marital_output_loss: 0.4266 - income_output_auc_roc: 0.6005 - marital_output_auc_roc: 0.8941 - val_loss: 0.6963 - val_income_output_loss: 0.4076 - val_marital_output_loss: 0.2888 - val_income_output_auc_roc: 0.6405 - val_marital_output_auc_roc: 0.9530
# Epoch 18/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.7655 - income_output_loss: 0.3586 - marital_output_loss: 0.4069 - income_output_auc_roc: 0.6694 - marital_output_auc_roc: 0.9013 - val_loss: 0.5368 - val_income_output_loss: 0.2581 - val_marital_output_loss: 0.2787 - val_income_output_auc_roc: 0.7966 - val_marital_output_auc_roc: 0.9553
# Epoch 19/50
# 199523/199523 [==============================] - 4s 20us/step - loss: 0.7058 - income_output_loss: 0.3150 - marital_output_loss: 0.3908 - income_output_auc_roc: 0.7118 - marital_output_auc_roc: 0.9064 - val_loss: 0.5200 - val_income_output_loss: 0.2392 - val_marital_output_loss: 0.2808 - val_income_output_auc_roc: 0.8103 - val_marital_output_auc_roc: 0.9581
# Epoch 20/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.6774 - income_output_loss: 0.2960 - marital_output_loss: 0.3814 - income_output_auc_roc: 0.7296 - marital_output_auc_roc: 0.9105 - val_loss: 0.4966 - val_income_output_loss: 0.2289 - val_marital_output_loss: 0.2677 - val_income_output_auc_roc: 0.8211 - val_marital_output_auc_roc: 0.9594
# Epoch 21/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.6497 - income_output_loss: 0.2801 - marital_output_loss: 0.3696 - income_output_auc_roc: 0.7422 - marital_output_auc_roc: 0.9151 - val_loss: 0.4734 - val_income_output_loss: 0.2180 - val_marital_output_loss: 0.2554 - val_income_output_auc_roc: 0.8422 - val_marital_output_auc_roc: 0.9629
# Epoch 22/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.6216 - income_output_loss: 0.2622 - marital_output_loss: 0.3593 - income_output_auc_roc: 0.7605 - marital_output_auc_roc: 0.9192 - val_loss: 0.4567 - val_income_output_loss: 0.2051 - val_marital_output_loss: 0.2516 - val_income_output_auc_roc: 0.8480 - val_marital_output_auc_roc: 0.9655
# Epoch 23/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.6014 - income_output_loss: 0.2549 - marital_output_loss: 0.3464 - income_output_auc_roc: 0.7694 - marital_output_auc_roc: 0.9236 - val_loss: 0.4456 - val_income_output_loss: 0.1995 - val_marital_output_loss: 0.2462 - val_income_output_auc_roc: 0.8521 - val_marital_output_auc_roc: 0.9673
# Epoch 24/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.5848 - income_output_loss: 0.2470 - marital_output_loss: 0.3378 - income_output_auc_roc: 0.7753 - marital_output_auc_roc: 0.9273 - val_loss: 0.4371 - val_income_output_loss: 0.1957 - val_marital_output_loss: 0.2414 - val_income_output_auc_roc: 0.8564 - val_marital_output_auc_roc: 0.9671
# Epoch 25/50
# 199523/199523 [==============================] - 4s 21us/step - loss: 0.5702 - income_output_loss: 0.2405 - marital_output_loss: 0.3297 - income_output_auc_roc: 0.7825 - marital_output_auc_roc: 0.9310 - val_loss: 0.4150 - val_income_output_loss: 0.1836 - val_marital_output_loss: 0.2314 - val_income_output_auc_roc: 0.8738 - val_marital_output_auc_roc: 0.9704
# Epoch 26/50
# 199523/199523 [==============================] - 4s 21us/step - loss: 0.5641 - income_output_loss: 0.2343 - marital_output_loss: 0.3298 - income_output_auc_roc: 0.7897 - marital_output_auc_roc: 0.9327 - val_loss: 0.4173 - val_income_output_loss: 0.1756 - val_marital_output_loss: 0.2417 - val_income_output_auc_roc: 0.8784 - val_marital_output_auc_roc: 0.9730
# Epoch 27/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.5483 - income_output_loss: 0.2267 - marital_output_loss: 0.3216 - income_output_auc_roc: 0.8021 - marital_output_auc_roc: 0.9341 - val_loss: 0.4002 - val_income_output_loss: 0.1725 - val_marital_output_loss: 0.2276 - val_income_output_auc_roc: 0.8854 - val_marital_output_auc_roc: 0.9733
# Epoch 28/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.5354 - income_output_loss: 0.2228 - marital_output_loss: 0.3127 - income_output_auc_roc: 0.8046 - marital_output_auc_roc: 0.9373 - val_loss: 0.3963 - val_income_output_loss: 0.1724 - val_marital_output_loss: 0.2238 - val_income_output_auc_roc: 0.8843 - val_marital_output_auc_roc: 0.9747
# Epoch 29/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.5221 - income_output_loss: 0.2177 - marital_output_loss: 0.3044 - income_output_auc_roc: 0.8106 - marital_output_auc_roc: 0.9404 - val_loss: 0.3954 - val_income_output_loss: 0.1719 - val_marital_output_loss: 0.2234 - val_income_output_auc_roc: 0.8887 - val_marital_output_auc_roc: 0.9760
# Epoch 30/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.5131 - income_output_loss: 0.2138 - marital_output_loss: 0.2993 - income_output_auc_roc: 0.8146 - marital_output_auc_roc: 0.9427 - val_loss: 0.3877 - val_income_output_loss: 0.1705 - val_marital_output_loss: 0.2171 - val_income_output_auc_roc: 0.8902 - val_marital_output_auc_roc: 0.9765
# Epoch 31/50
# 199523/199523 [==============================] - 4s 21us/step - loss: 0.5015 - income_output_loss: 0.2103 - marital_output_loss: 0.2912 - income_output_auc_roc: 0.8187 - marital_output_auc_roc: 0.9445 - val_loss: 0.3825 - val_income_output_loss: 0.1696 - val_marital_output_loss: 0.2128 - val_income_output_auc_roc: 0.8920 - val_marital_output_auc_roc: 0.9779
# Epoch 32/50
# 199523/199523 [==============================] - 4s 21us/step - loss: 0.4919 - income_output_loss: 0.2073 - marital_output_loss: 0.2846 - income_output_auc_roc: 0.8233 - marital_output_auc_roc: 0.9466 - val_loss: 0.3708 - val_income_output_loss: 0.1672 - val_marital_output_loss: 0.2036 - val_income_output_auc_roc: 0.8913 - val_marital_output_auc_roc: 0.9791
# Epoch 33/50
# 199523/199523 [==============================] - 4s 20us/step - loss: 0.4859 - income_output_loss: 0.2058 - marital_output_loss: 0.2801 - income_output_auc_roc: 0.8255 - marital_output_auc_roc: 0.9482 - val_loss: 0.3661 - val_income_output_loss: 0.1666 - val_marital_output_loss: 0.1995 - val_income_output_auc_roc: 0.8946 - val_marital_output_auc_roc: 0.9796
# Epoch 34/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.4753 - income_output_loss: 0.2024 - marital_output_loss: 0.2729 - income_output_auc_roc: 0.8295 - marital_output_auc_roc: 0.9501 - val_loss: 0.3642 - val_income_output_loss: 0.1676 - val_marital_output_loss: 0.1966 - val_income_output_auc_roc: 0.8946 - val_marital_output_auc_roc: 0.9809
# Epoch 35/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.4718 - income_output_loss: 0.2017 - marital_output_loss: 0.2702 - income_output_auc_roc: 0.8316 - marital_output_auc_roc: 0.9516 - val_loss: 0.3537 - val_income_output_loss: 0.1646 - val_marital_output_loss: 0.1891 - val_income_output_auc_roc: 0.8972 - val_marital_output_auc_roc: 0.9815
# Epoch 36/50
# 199523/199523 [==============================] - 5s 25us/step - loss: 0.4632 - income_output_loss: 0.2000 - marital_output_loss: 0.2631 - income_output_auc_roc: 0.8343 - marital_output_auc_roc: 0.9532 - val_loss: 0.3535 - val_income_output_loss: 0.1619 - val_marital_output_loss: 0.1916 - val_income_output_auc_roc: 0.8981 - val_marital_output_auc_roc: 0.9819
# Epoch 37/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.4570 - income_output_loss: 0.1988 - marital_output_loss: 0.2582 - income_output_auc_roc: 0.8351 - marital_output_auc_roc: 0.9553 - val_loss: 0.3540 - val_income_output_loss: 0.1628 - val_marital_output_loss: 0.1912 - val_income_output_auc_roc: 0.8989 - val_marital_output_auc_roc: 0.9822
# Epoch 38/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.4482 - income_output_loss: 0.1958 - marital_output_loss: 0.2524 - income_output_auc_roc: 0.8396 - marital_output_auc_roc: 0.9568 - val_loss: 0.3427 - val_income_output_loss: 0.1592 - val_marital_output_loss: 0.1835 - val_income_output_auc_roc: 0.9015 - val_marital_output_auc_roc: 0.9821
# Epoch 39/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.4402 - income_output_loss: 0.1930 - marital_output_loss: 0.2472 - income_output_auc_roc: 0.8424 - marital_output_auc_roc: 0.9591 - val_loss: 0.3393 - val_income_output_loss: 0.1598 - val_marital_output_loss: 0.1795 - val_income_output_auc_roc: 0.9017 - val_marital_output_auc_roc: 0.9829
# Epoch 40/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.4279 - income_output_loss: 0.1917 - marital_output_loss: 0.2362 - income_output_auc_roc: 0.8446 - marital_output_auc_roc: 0.9630 - val_loss: 0.3264 - val_income_output_loss: 0.1586 - val_marital_output_loss: 0.1679 - val_income_output_auc_roc: 0.9032 - val_marital_output_auc_roc: 0.9824
# Epoch 41/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.4050 - income_output_loss: 0.1857 - marital_output_loss: 0.2193 - income_output_auc_roc: 0.8579 - marital_output_auc_roc: 0.9684 - val_loss: 0.3233 - val_income_output_loss: 0.1594 - val_marital_output_loss: 0.1639 - val_income_output_auc_roc: 0.9032 - val_marital_output_auc_roc: 0.9833
# Epoch 42/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.3911 - income_output_loss: 0.1799 - marital_output_loss: 0.2112 - income_output_auc_roc: 0.8696 - marital_output_auc_roc: 0.9708 - val_loss: 0.3139 - val_income_output_loss: 0.1574 - val_marital_output_loss: 0.1565 - val_income_output_auc_roc: 0.9052 - val_marital_output_auc_roc: 0.9850
# Epoch 43/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.3823 - income_output_loss: 0.1774 - marital_output_loss: 0.2049 - income_output_auc_roc: 0.8730 - marital_output_auc_roc: 0.9725 - val_loss: 0.3135 - val_income_output_loss: 0.1563 - val_marital_output_loss: 0.1572 - val_income_output_auc_roc: 0.9046 - val_marital_output_auc_roc: 0.9845
# Epoch 44/50
# 199523/199523 [==============================] - 4s 21us/step - loss: 0.3795 - income_output_loss: 0.1764 - marital_output_loss: 0.2031 - income_output_auc_roc: 0.8742 - marital_output_auc_roc: 0.9730 - val_loss: 0.3118 - val_income_output_loss: 0.1565 - val_marital_output_loss: 0.1553 - val_income_output_auc_roc: 0.9053 - val_marital_output_auc_roc: 0.9852
# Epoch 45/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.3767 - income_output_loss: 0.1757 - marital_output_loss: 0.2010 - income_output_auc_roc: 0.8760 - marital_output_auc_roc: 0.9739 - val_loss: 0.3128 - val_income_output_loss: 0.1549 - val_marital_output_loss: 0.1579 - val_income_output_auc_roc: 0.9078 - val_marital_output_auc_roc: 0.9846
# Epoch 46/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.3695 - income_output_loss: 0.1745 - marital_output_loss: 0.1951 - income_output_auc_roc: 0.8764 - marital_output_auc_roc: 0.9750 - val_loss: 0.3054 - val_income_output_loss: 0.1540 - val_marital_output_loss: 0.1514 - val_income_output_auc_roc: 0.9083 - val_marital_output_auc_roc: 0.9856
# Epoch 47/50
# 199523/199523 [==============================] - 5s 24us/step - loss: 0.3656 - income_output_loss: 0.1716 - marital_output_loss: 0.1940 - income_output_auc_roc: 0.8800 - marital_output_auc_roc: 0.9755 - val_loss: 0.3047 - val_income_output_loss: 0.1539 - val_marital_output_loss: 0.1509 - val_income_output_auc_roc: 0.9091 - val_marital_output_auc_roc: 0.9858
# Epoch 48/50
# 199523/199523 [==============================] - 5s 23us/step - loss: 0.3586 - income_output_loss: 0.1718 - marital_output_loss: 0.1868 - income_output_auc_roc: 0.8803 - marital_output_auc_roc: 0.9771 - val_loss: 0.3020 - val_income_output_loss: 0.1527 - val_marital_output_loss: 0.1494 - val_income_output_auc_roc: 0.9118 - val_marital_output_auc_roc: 0.9859
# Epoch 49/50
# 199523/199523 [==============================] - 4s 22us/step - loss: 0.3493 - income_output_loss: 0.1697 - marital_output_loss: 0.1796 - income_output_auc_roc: 0.8846 - marital_output_auc_roc: 0.9789 - val_loss: 0.2982 - val_income_output_loss: 0.1519 - val_marital_output_loss: 0.1463 - val_income_output_auc_roc: 0.9146 - val_marital_output_auc_roc: 0.9861
# Epoch 50/50
# 199523/199523 [==============================] - 5s 25us/step - loss: 0.3429 - income_output_loss: 0.1691 - marital_output_loss: 0.1737 - income_output_auc_roc: 0.8866 - marital_output_auc_roc: 0.9797 - val_loss: 0.2837 - val_income_output_loss: 0.1521 - val_marital_output_loss: 0.1316 - val_income_output_auc_roc: 0.9169 - val_marital_output_auc_roc: 0.9876
# 49881/49881 [==============================] - 5s 97us/step
# Test results: [0.28606210884819366, 0.15212419514890896, 0.13393791359267396, 0.8649790902969695, 0.9871983993553951]
# Test income_output Loss: 0.28606210884819366
# Test income_output AUC: 0.15212419514890896
# Test marital_output AUC: 0.13393791359267396
